# %%
valor01 = int(input("Entre com o inicio do vetor"))
valor02 = int(input("Entre com o final do vetor"))
for intervalo in range(valor01, valor02 +1):
    if (intervalo%2 == 0):
        print(intervalo)

# %%
bacteriaA = 4
bacteriaB = 10
qtd_dias = 0
while (bacteriaA <= bacteriaB):
    qtd_dias += 1
    bacteriaA += 1
print(qtd_dias)
# Out:
# 7

# %%
# 1) Faça um programa que tenha a seguinte lista contendo os valores de gastos de uma empresa de papel 
# [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]. 
# Com esses valores, faça um programa que calcule a média de gastos. Dica: use as funções built-in sum() e len().

Loja_Papel = {'Precos': [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]}
print( 'Soma: ', sum(Loja_Papel['Precos']) )
print( 'Tamanho: ', len(Loja_Papel['Precos']) )
print( 'Média: ', sum(Loja_Papel['Precos']) / len(Loja_Papel['Precos']) )
# Out:
# Soma:  31442.22
# Tamanho:  10
# Média:  3144.222

# %%
# 2) Com os mesmos dados da questão anterior, defina quantas compras foram realizadas acima de 3000 reais e calcule a porcentagem quanto ao total de compras.
cont = 0
for itens in Loja_Papel['Precos']:
    if itens > 3000:
        cont += 1
print('Total de compras acima de r$3000.00: ', cont)
# Out:
# Total de compras acima de r$3000.00:  7

# %%
# 3) Faça um código que colete em uma lista 5 números inteiros quaisquer e imprima a lista. Exemplo: [1,4,7,2,4].
numeros = []
for i in range(5):
    numeros.append(int(input('Digite um numero')))
print(f'Lista de números: {numeros}' )
# 4) Colete novamente 5 inteiros e imprima a lista em ordem inversa à enviada.
print(f'Lista de números invertida: {numeros[::-1]}')
# Out:
# Lista de números: [98, 8, 7, 6, 5]
# Lista de números invertida: [5, 6, 7, 8, 98]

# %%
# 5) Faça um programa que, ao inserir um número qualquer, cria uma lista contendo todos os números primos entre 1 e o número digitado.
numeros_primos = []
num_primo = int(input('Entre como numero limite para gerar os primos: '))
cont = 0
while(cont < num_primo):
